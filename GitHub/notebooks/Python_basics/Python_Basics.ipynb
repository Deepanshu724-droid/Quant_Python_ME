# %% [markdown]
# # Variables, data types

# %%
print("hello world")
Data = "1,2,3,4"
mean = 2.5
Meadian = 2.5
print(Data)
print(mean)
print(Meadian)

a= 123
b= "data types"
c= True
d= None
print("The type of a is ", type(a))
print("The type of a is ", type(b))
print("The type of a is ", type(c))
print("The type of a is ", type(d))
# Out:
# hello world
# 1,2,3,4
# 2.5
# 2.5
# The type of a is  <class 'int'>
# The type of a is  <class 'str'>
# The type of a is  <class 'bool'>
# The type of a is  <class 'NoneType'>

# %% [markdown]
# # if - else

# %%
is_male= True

if is_male:
    print("You are a male")
else:
    print("You are not male")
is_female= False

if is_female:
    print("you are a better women")
else:
    print("you can be a better women")
# Out:
# You are a male
# you can be a better women

# %% [markdown]
# # loops

# %%
friends= ["ayan"," priyanka","ayush"]
for index in range(5):
    print(index)
    if index == 0:
       print("first iteration")
    else:
        print("first not")
# Out:
# 0
# first iteration
# 1
# first not
# 2
# first not
# 3
# first not
# 4
# first not

# %% [markdown]
# # Functions

# %%
def say_hi():
    print("hello user")
say_hi()

def say_hi(name):
    print("hello " +name)
say_hi("DON")
# Out:
# hello user
# hello DON

# %% [markdown]
# # LISTS

# %%
list1= [8,3,4,5,{3,4,5},],["Apple, MANGO,Banana,Chatgpt"]
print(list1[0] [0] )
# Out:
# 8

# %% [markdown]
# # BUILDING A BASIC CALCULATOR

# %%
Num_1= input("give me a number")
Num_2= input("give me another number")
res= int(Num_1)+int(Num_2)
print(res)
# Out:
# give me a number 3
# give me another number 3
# 6

# %% [markdown]
# # Fun with algebra

# %%
print("happy \n Nation")

print(3*4)

print(3+(3+4))

print(max(4,6))

print(int(3.7))
# Out:
# happy
#  Nation
# 12
# 10
# 6
# 3
